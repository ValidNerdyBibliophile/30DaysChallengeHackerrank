# %% [markdown]
# ![Screenshot%20%2820%29.png](attachment:Screenshot%20%2820%29.png)

# %%
import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    for i in range(1, 11):
        print(n, 'x', i, '=', n*i)
# Out:
# 90
# 90 x 1 = 90
# 90 x 2 = 180
# 90 x 3 = 270
# 90 x 4 = 360
# 90 x 5 = 450
# 90 x 6 = 540
# 90 x 7 = 630
# 90 x 8 = 720
# 90 x 9 = 810
# 90 x 10 = 900
